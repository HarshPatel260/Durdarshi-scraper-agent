# %%
# !pip install --upgrade openai
# !pip install pinecone
# !pip install langchain
# !pip install langchain-community
# !pip install pandas
# !pip install dotenv
# !pip install numpy
# Out:
# Collecting openai
#   Downloading openai-1.90.0-py3-none-any.whl.metadata (26 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
#      ---------------------------------------- 0.0/68.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/68.0 kB ? eta -:--:--
#      ---------------------------------------- 68.0/68.0 kB 3.8 MB/s eta 0:00:00
# Collecting sniffio (from openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.14.0)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai)
#   Downloading certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.90.0-py3-none-any.whl (734 kB)
#    ---------------------------------------- 0.0/734.6 kB ? eta -:--:--
#    --------------------- ----------------- 409.6/734.6 kB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  727.0/734.6 kB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 734.6/734.6 kB 7.7 MB/s eta 0:00:00
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.9 kB ? eta -:--:--
#    ---------------------------------------- 100.9/100.9 kB ? eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB ? eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#    ---------------------------------------- 78.8/78.8 kB 4.3 MB/s eta 0:00:00
# Downloading jiter-0.10.0-cp311-cp311-win_amd64.whl (209 kB)
#    ---------------------------------------- 0.0/209.2 kB ? eta -:--:--
#    ---------------------------------------- 209.2/209.2 kB ? eta 0:00:00
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#    ---------------------------------------- 0.0/444.8 kB ? eta -:--:--
#    --------------------------------------- 444.8/444.8 kB 27.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------ --------------- 1.2/2.0 MB 37.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 24.9 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB 3.8 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
#    ---------------------------------------- 0.0/157.7 kB ? eta -:--:--
#    ---------------------------------------- 157.7/157.7 kB 9.8 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-inspection, tqdm, sniffio, pydantic-core, jiter, idna, h11, distro, certifi, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.9.0 certifi-2025.6.15 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 jiter-0.10.0 openai-1.90.0 pydantic-2.11.7 pydantic-core-2.33.2 sniffio-1.3.1 tqdm-4.67.1 typing-inspection-0.4.1
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\abhin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting pinecone
#   Downloading pinecone-7.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pinecone) (2025.6.15)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone)
#   Downloading pinecone_plugin_assistant-1.7.0-py3-none-any.whl.metadata (28 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pinecone) (4.14.0)
# Collecting urllib3>=1.26.0 (from pinecone)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting packaging<25.0,>=24.2 (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting requests<3.0.0,>=2.32.3 (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six>=1.5 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone)
#   Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.10)
# Downloading pinecone-7.2.0-py3-none-any.whl (524 kB)
#    ---------------------------------------- 0.0/524.3 kB ? eta -:--:--
#    ---------------------------- ----------- 368.6/524.3 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 524.3/524.3 kB 6.6 MB/s eta 0:00:00
# Downloading pinecone_plugin_assistant-1.7.0-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/240.0 kB ? eta -:--:--
#    ---------------------------------------- 240.0/240.0 kB 7.4 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#    ---------------------------------------- 0.0/129.8 kB ? eta -:--:--
#    ---------------------------------------- 129.8/129.8 kB 7.5 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.5 kB ? eta -:--:--
#    ---------------------------------------- 65.5/65.5 kB 3.7 MB/s eta 0:00:00
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.8 kB ? eta -:--:--
#    ---------------------------------------- 64.8/64.8 kB 3.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl (105 kB)
#    ---------------------------------------- 0.0/105.4 kB ? eta -:--:--
#    ---------------------------------------- 105.4/105.4 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, pinecone-plugin-interface, packaging, charset_normalizer, requests, pinecone-plugin-assistant, pinecone
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed charset_normalizer-3.4.2 packaging-24.2 pinecone-7.2.0 pinecone-plugin-assistant-1.7.0 pinecone-plugin-interface-0.0.7 requests-2.32.4 urllib3-2.5.0
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\abhin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting langchain
#   Downloading langchain-0.3.26-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.66 (from langchain)
#   Downloading langchain_core-0.3.66-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain) (2.11.7)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.41-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain) (2.32.4)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.66->langchain)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.66->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.10.18-cp311-cp311-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.0 kB ? eta -:--:--
#      ---------------------------------------- 43.0/43.0 kB 1.0 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.3-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.26-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.0 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 12.7 MB/s eta 0:00:00
# Downloading langchain_core-0.3.66-py3-none-any.whl (438 kB)
#    ---------------------------------------- 0.0/438.9 kB ? eta -:--:--
#    --------------------------------------- 438.9/438.9 kB 13.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Downloading langsmith-0.4.1-py3-none-any.whl (364 kB)
#    ---------------------------------------- 0.0/364.6 kB ? eta -:--:--
#    --------------------------------------- 364.6/364.6 kB 22.1 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
#    ---------------------------------------- 0.0/162.0 kB ? eta -:--:--
#    --------------------------------------- 162.0/162.0 kB 10.1 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.41-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------------------------- ------------ 1.4/2.1 MB 30.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 22.6 MB/s eta 0:00:00
# Downloading greenlet-3.2.3-cp311-cp311-win_amd64.whl (297 kB)
#    ---------------------------------------- 0.0/297.0 kB ? eta -:--:--
#    ---------------------------------------- 297.0/297.0 kB 9.3 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.18-cp311-cp311-win_amd64.whl (134 kB)
#    ---------------------------------------- 0.0/134.6 kB ? eta -:--:--
#    ---------------------------------------- 134.6/134.6 kB ? eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl (495 kB)
#    ---------------------------------------- 0.0/495.4 kB ? eta -:--:--
#    --------------------------------------- 495.4/495.4 kB 15.7 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: zstandard, tenacity, PyYAML, orjson, jsonpointer, greenlet, SQLAlchemy, requests-toolbelt, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.41 greenlet-3.2.3 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.26 langchain-core-0.3.66 langchain-text-splitters-0.3.8 langsmith-0.4.1 orjson-3.10.18 requests-toolbelt-1.0.0 tenacity-9.1.2 zstandard-0.23.0
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\abhin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting langchain-community
#   Downloading langchain_community-0.3.26-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community) (0.3.66)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.12.13-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-community) (0.4.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numpy>=1.26.2 (from langchain-community)
#   Downloading numpy-2.3.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 1.6 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.7.0-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.5.0-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.3.2-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.20.1-cp311-cp311-win_amd64.whl.metadata (76 kB)
#      ---------------------------------------- 0.0/76.3 kB ? eta -:--:--
#      ---------------------------------------- 76.3/76.3 kB 4.1 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain-community) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: anyio in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.26-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.5 MB 8.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.5 MB 7.2 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.5 MB 6.9 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.5 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 6.4 MB/s eta 0:00:00
# Downloading aiohttp-3.12.13-cp311-cp311-win_amd64.whl (451 kB)
#    ---------------------------------------- 0.0/451.4 kB ? eta -:--:--
#    --------------------------------- ------ 378.9/451.4 kB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 451.4/451.4 kB 7.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading numpy-2.3.1-cp311-cp311-win_amd64.whl (13.0 MB)
#    ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.9/13.0 MB 26.6 MB/s eta 0:00:01
#    ------ --------------------------------- 2.0/13.0 MB 25.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.4/13.0 MB 27.4 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/13.0 MB 28.9 MB/s eta 0:00:01
#    ------------------- -------------------- 6.5/13.0 MB 29.5 MB/s eta 0:00:01
#    ------------------------ --------------- 8.0/13.0 MB 29.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.4/13.0 MB 30.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.9/13.0 MB 31.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.5/13.0 MB 31.1 MB/s eta 0:00:01
#    ---------------------------------------  13.0/13.0 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------- 13.0/13.0 MB 26.2 MB/s eta 0:00:00
# Downloading pydantic_settings-2.10.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.2 kB ? eta -:--:--
#    ---------------------------------------- 45.2/45.2 kB ? eta 0:00:00
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.8 kB ? eta -:--:--
#    ---------------------------------------- 63.8/63.8 kB 3.6 MB/s eta 0:00:00
# Downloading frozenlist-1.7.0-cp311-cp311-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.0 kB ? eta -:--:--
#    ---------------------------------------- 44.0/44.0 kB 2.3 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#    ---------------------------------------- 50.9/50.9 kB 2.7 MB/s eta 0:00:00
# Downloading multidict-6.5.0-cp311-cp311-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#    ---------------------------------------- 44.4/44.4 kB 2.1 MB/s eta 0:00:00
# Downloading propcache-0.3.2-cp311-cp311-win_amd64.whl (41 kB)
#    ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#    ---------------------------------------- 41.5/41.5 kB ? eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.20.1-cp311-cp311-win_amd64.whl (86 kB)
#    ---------------------------------------- 0.0/86.7 kB ? eta -:--:--
#    ---------------------------------------- 86.7/86.7 kB 5.1 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-community
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.13 aiosignal-1.3.2 attrs-25.3.0 dataclasses-json-0.6.7 frozenlist-1.7.0 httpx-sse-0.4.0 langchain-community-0.3.26 marshmallow-3.26.1 multidict-6.5.0 mypy-extensions-1.1.0 numpy-2.3.1 propcache-0.3.2 pydantic-settings-2.10.0 python-dotenv-1.1.0 typing-inspect-0.9.0 yarl-1.20.1
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\abhin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting pandas
#   Downloading pandas-2.3.0-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.0-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.1 MB 3.6 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/11.1 MB 5.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/11.1 MB 7.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.1 MB 6.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.1 MB 7.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.1 MB 7.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.1 MB 8.2 MB/s eta 0:00:02
#    -------------- ------------------------- 4.0/11.1 MB 11.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.1 MB 13.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.0/11.1 MB 15.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.5/11.1 MB 16.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.1 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 19.8 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#    --------------------------------------- 509.2/509.2 kB 31.2 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#    --------------------------------------- 347.8/347.8 kB 21.1 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.3.0 pytz-2025.2 tzdata-2025.2
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\abhin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: python-dotenv in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dotenv) (1.1.0)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: dotenv
# Successfully installed dotenv-0.9.9
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\abhin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\abhin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.1)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\abhin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from openai import OpenAI
import os
from pinecone import Pinecone, ServerlessSpec
from datetime import datetime

from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone as LangchainPinecone
from langchain.vectorstores import Chroma
from langchain.schema import Document

import pandas as pd 
import numpy as np

from dotenv import load_dotenv

# %%
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY') 
# os.environ["PINECONE_API_KEY"] = os.getenv('PINECONE_API_KEY')

# %%
client = OpenAI()
# date= datetime.now().strftime("%Y-%m-%d")

prompt = '''

Goal:
I want a list of the best News websites which shows the top engaging news from whole world. While returning, give 5 websites which we have given below and 5 websites from your side. Remember, the 5 websites that you will give needs to be different from those that we have provided you.

Our websites -

international-
https://www.theguardian.com/international
https://www.dw.com/en
https://www.cnn.com

indian-
https://indianexpress.com

china-
https://www.scmp.com


Return Format:
We will provide 5 websites and you have to add 5 more websites to the list .out of which 3 should be sites focused on global top news ,1 should be focused on news from india and 1 should be focused on china. In total, give me 10 websites


Warning:
Be careful to make sure that the name and website address is correct .and the websites are trustworthy to show true and unobstructed news.
as given above 5 sites should be included in the list and should follow the EXACT format as shown in example. 
Make sure in the end we have exactly 10 sites in the Final list. NO MORE NO LESS. 

Example: News Website:
international-
1.https://www.theguardian.com/international
2.https://www.dw.com/en
3.https://www.cnn.com
4.[Your site 1]
5.[Your site 2]
6.[Your site 3]

indian-
7.https://indianexpress.com
8.[Your site 4]


china-
9.https://www.scmp.com
10.[Your site 5]

'''

response = client.chat.completions.create(
    model="gpt-4o",  
    messages=[{"role": "user", "content": prompt}],
    temperature=0.7
)

news_text = response.choices[0].message.content.strip()
print("📰 GPT Response:\n", news_text)
# Out:
# 📰 GPT Response:
#  News Website:
# international-
# 1. https://www.theguardian.com/international
# 2. https://www.dw.com/en
# 3. https://www.cnn.com
# 4. https://www.bbc.com/news
# 5. https://www.reuters.com
#
# indian-
# 6. https://indianexpress.com
# 7. https://www.timesofindia.com
#
# china-
# 8. https://www.scmp.com
# 9. https://www.xinhuanet.com
# 10. https://www.globaltimes.cn

# %%
client = OpenAI()

date= datetime.now().strftime("%Y-%m-%d")

prompt = f'''

websites:
{news_text}

Goal:
Important - Main goal should be to provide the most engaging information so we can get the most user traffic on our websites.
For the links that I have provided above can you scrape the latest news present on all the webpages from the websites and give me the textual information in a structured format for the given date {date}?
Also summarize these news meaningfully in 3 sentences. i need further information so give read friendly tags like Location,Date,source


Note: I need the most engaging news from these websites.  

Return Format:
The text that you scrape should be structured as follows:
Name of webpage:
Date:
News Headline:
The actual news:

Remember, you have to return top 10 news from all the websites. 7 should be from the links given above and 3 should be from your side which you think will garner the most engagement from the readers. 


Warning:
I don't want the unnecessary information such as google ads on the website or the text under Terms and Conditions footer information, etc.

Example:
Name of news website: Bloomberg News
Date: 08-06-2025
News Headline: Tesla Shares drop to 53 %.
News Text: Due to the fight between Trump and Elon Musk the company Tesla faces a major loss in share price. The drop is considered to be 53%.



'''

response = client.responses.create(
    model="gpt-4o",
    tools=[{"type": "web_search_preview"}],
    input= prompt,
)
print(response.output_text)

# news_text = response.choices[0].message.content.strip()
# print("📰 GPT Response:\n", news_text)
# Out:
# Here are the top 10 news stories from June 22, 2025, compiled from the provided sources and additional engaging news items:
#
# **1. Name of news website:** Reuters
# **Date:** June 22, 2025
# **News Headline:** LNG Canada Produces First Liquefied Natural Gas for Export
# **News Text:** LNG Canada, a joint venture led by Shell, has produced its first liquefied natural gas (LNG) for export from its facility in Kitimat, British Columbia. This marks Canada's first large-scale LNG project to begin production and the first major North American facility with direct access to the Pacific coast, significantly reducing shipping times to Asia. The first export cargo is expected to ship by early July. ([reuters.com](https://www.reuters.com/business/energy/lng-canada-produces-first-liquefied-natural-gas-export-sources-say-2025-06-22/?utm_source=openai))
#
# **2. Name of news website:** Reuters
# **Date:** June 22, 2025
# **News Headline:** Twenty Killed in Suicide Bombing at Damascus Church
# **News Text:** A suicide bombing at the Mar Elias Church in Damascus, Syria, resulted in at least 20 deaths and 52 injuries. The attacker, identified as a member of the Islamic State, entered the church, opened fire, and then detonated an explosive vest. This is the first successful suicide attack on a church in Damascus since the overthrow of Bashar al-Assad in December. ([reuters.com](https://www.reuters.com/world/middle-east/blast-rocks-church-syrias-damascus-witnesses-say-2025-06-22/?utm_source=openai))
#
# **3. Name of news website:** Reuters
# **Date:** June 22, 2025
# **News Headline:** Air India Reduces Narrowbody Jet Routes, Suspends Two International Flights
# **News Text:** Air India announced a temporary reduction of less than 5% in its narrowbody jet routes to enhance operational stability following a deadly plane crash earlier in June. The adjustments include suspending two daily international flights to Singapore and disrupting services on 19 domestic routes through July 15. These strategic cutbacks are part of efforts to stabilize the airline's overall network in the wake of the tragic incident. ([reuters.com](https://www.reuters.com/world/india/air-india-cuts-less-than-5-narrowbody-jet-routes-suspends-two-international-2025-06-22/?utm_source=openai))
#
# **4. Name of news website:** Reuters
# **Date:** June 22, 2025
# **News Headline:** US Bombing of Iran Started with a Fake-Out
# **News Text:** The U.S. launched Operation "Midnight Hammer," a large-scale airstrike targeting Iran's primary nuclear facilities. The operation began with a deceptive maneuver involving visible B-2 bombers as a decoy, while the real strike force flew undetected. The bombers dropped 14 massive GBU-57 bunker-buster bombs, resulting in severe damage to all targeted nuclear sites. ([reuters.com](https://www.reuters.com/business/aerospace-defense/us-bombing-iran-started-with-fake-out-2025-06-22/?utm_source=openai))
#
# **5. Name of news website:** Reuters
# **Date:** June 21, 2025
# **News Headline:** Injured Ruud Pulls Out of Wimbledon
# **News Text:** Norwegian tennis star Casper Ruud has withdrawn from Wimbledon due to an ongoing knee injury. Currently ranked world No. 16, Ruud has not played on the men's tour since his unexpected second-round exit at the French Open. He plans to aim for a return at the Swiss Open in Gstaad, which begins on July 14. ([reuters.com](https://www.reuters.com/sports/tennis/injured-ruud-pulls-out-wimbledon-2025-06-21/?utm_source=openai))
#
# **6. Name of news website:** Reuters
# **Date:** June 22, 2025
# **News Headline:** Ukraine Fighting 10,000 Russian Troops in Kursk Region
# **News Text:** Ukraine's top military commander reported that Ukrainian forces are engaging around 10,000 Russian troops in Russia’s Kursk region. Ukraine currently controls approximately 90 square kilometers in this area as a preemptive measure to deter Russian attacks. This operation has tied down Russian units that could have been deployed to the Donetsk region. ([reuters.com](https://www.reuters.com/business/aerospace-defense/ukraine-fighting-10000-russian-troops-kursk-region-ukrainian-commander-says-2025-06-22/?utm_source=openai))
#
# **7. Name of news website:** The Guardian
# **Date:** June 22, 2025
# **News Headline:** Iran President Says US 'Must Receive a Response' to Attack on Nuclear Sites
# **News Text:** Iran's President has stated that the United States "must receive a response" following the recent airstrikes on Iran's nuclear facilities. The statement comes amid escalating tensions and international calls for restraint. The situation has drawn widespread condemnation and concern over potential regional instability.
#
# **8. Name of news website:** DW
# **Date:** June 20, 2025
# **News Headline:** Israel-Iran: Germany, France, UK Seek Diplomatic Solution
# **News Text:** Germany, France, and the UK are seeking a diplomatic solution to the escalating conflict between Israel and Iran. The countries have called for restraint and emphasized the importance of dialogue to prevent further escalation. The international community remains concerned about the potential for widespread regional instability.
#
# **9. Name of news website:** Reuters
# **Date:** June 22, 2025
# **News Headline:** World Awaits Iran's Response After US Hits Nuclear Sites
# **News Text:** The international community is on edge as it awaits Iran's response to the recent U.S. airstrikes on its nuclear facilities. Western hawks have long hoped military action would spark regime change in Iran, while opponents fear it could trigger chaos and bloodshed that could spill well beyond its borders. The situation remains highly volatile, with potential implications for global security and the economy.
#
# **10. Name of news website:** Reuters
# **Date:** June 22, 2025
# **News Headline:** Investors Brace for Oil Price Spike After US Bombs Iran Nuclear Sites
# **News Text:** Investors are preparing for a potential spike in oil prices following the U.S. airstrikes on Iran's nuclear facilities. The attacks have raised concerns about disruptions to global oil supply and increased geopolitical tensions. Markets are closely monitoring the situation for further developments.
#
# **Summary:**
#
# On June 22, 2025, significant global events unfolded, including the U.S. launching airstrikes on Iran's nuclear facilities, prompting Iran's president to vow a response, and the international community expressing concern over potential regional instability. In Syria, a suicide bombing at a Damascus church resulted in numerous casualties, marking a resurgence of violence in the region. Additionally, economic implications arose as investors braced for potential oil price spikes due to escalating tensions in the Middle East.

# %% [markdown]
# ### Code to push text to the vector database

# %%
lines = [line.strip() for line in news_text.split("\n") if line.strip()]
documents = [Document(page_content=line) for line in lines]

documents

# %%
PINECONE_REGION = "us-east-1"
PINECONE_API_KEY = os.environ["PINECONE_API_KEY"]

pc= Pinecone(api_key= PINECONE_API_KEY)

INDEX_NAME = "latest-news"  


# Check and create index if not exists
if INDEX_NAME not in pc.list_indexes().names():
    pc.create_index(
        name=INDEX_NAME,
        dimension=1536,  # Dimension for OpenAI embeddings
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region=PINECONE_REGION
        )
    )

# Wait for index to be ready
index = pc.Index(INDEX_NAME)

# %%
existing_indexes = pc.list_indexes().names()

# Check if your index exists
index_name = "latest-news"
if index_name in existing_indexes:
    print(f"✅ Index '{index_name}' exists.")
else:
    print(f"❌ Index '{index_name}' does NOT exist.")

# %%
# Step 4: Initialize OpenAI embeddings
embedding_model = OpenAIEmbeddings()

# Step 5: Store documents in Pinecone using LangChain
namespace = "news-dump-" + str(uuid.uuid4())[:8]

vectorstore = LangchainPinecone.from_documents(
    documents=documents,
    embedding=embedding_model,
    index_name=index_name,
    namespace=namespace
)

print(f"✅ News saved to Pinecone under namespace: {namespace}")
